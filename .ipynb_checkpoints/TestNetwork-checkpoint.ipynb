# %%
import tensorflow as tf
import numpy as np
from skimage import io
from main import build_model
import matplotlib.pyplot as plt
# %matplotlib inline

inp = tf.placeholder(tf.float32,shape=[None,224,224,4],name='input')
net = build_model(inp,"vgg16")

# Attach sigmoid and reshape
out= tf.reshape(tf.sigmoid(net),[-1,56,56,1])


saver = tf.train.Saver()
sess = tf.InteractiveSession()
saver.restore(sess, 'exp/test1/epoch-26.ckpt')

print("Model Loaded")
# Out:
# Model Loaded

# %%
from dataprovider.preprocess import vgg_preprocess
import os
from skimage import transform
BASE_DIR = os.path.join(os.path.expanduser('~'),'DAVIS')
IMAGESETS = os.path.join('ImageSets','480p')
    
RESIZE_HEIGHT = 224
RESIZE_WIDTH = 224

def read_image(imageFile,prevMaskFile):
        
    # Fix full file path
    rgbFile =BASE_DIR + imageFile
    maskFile = BASE_DIR + prevMaskFile
        
    # Read images 
    rgb = io.imread(rgbFile)
    mask = io.imread(maskFile,as_grey=True)
    mask = np.expand_dims(mask,axis=2)
        
    # Concatenate images
    image =  np.concatenate((rgb, mask), 2)
    
    # Resize 
    image = transform.resize(image,[RESIZE_HEIGHT,RESIZE_WIDTH])
       
    #io.imshow(image[:,:,0:3])  
    print('Max',image.max(),image.min())
    image = image*255
    plt.imshow(image[:,:,0:3].astype(np.uint8)) 
    
    
    image = np.expand_dims(image,axis=0)
    
    image = vgg_preprocess(image)
    
    return image
test_img = ['/JPEGImages/480p/bear/00004.jpg' ,'/Annotations/480p/bear/00003.png']
v = read_image(test_img[0],test_img[1])
# Out:
# 2016-09-27 18:35:39,519 - PIL.PngImagePlugin - DEBUG - STREAM b'IHDR' 16 13
# 2016-09-27 18:35:39,520 - PIL.PngImagePlugin - DEBUG - STREAM b'IDAT' 41 2880
# Max 1.0 0.0

# %%
from skimage import morphology

img_list = [['/JPEGImages/480p/bear/00004.jpg' ,'/Annotations/480p/bear/00003.png'],
['/JPEGImages/480p/bear/00005.jpg' ,'/Annotations/480p/bear/00005.png']]

_R_MEAN = 123.68
_G_MEAN = 116.78
_B_MEAN = 103.94
_M_MEAN = 127

image = readImage(img[0][0],img[0][1])
image[0,:,:,3] = morphology.erosion(image[0,:,:,3],np.ones([15,15]))

result = sess.run([out],feed_dict={inp:image})
result[0].shape
plt.figure()
plt.subplot(1,3,1)
rgb = image[0,:,:,0:3]
print(rgb.shape)
means = [_R_MEAN, _G_MEAN ,_B_MEAN]
rgb = rgb + means
plt.imshow(rgb.astype(np.uint8))
plt.subplot(1,3,2)
plt.imshow(image[0,:,:,3])
plt.subplot(1,3,3)
plt.imshow(result[0][0,:,:,0])
# Out:
# 2016-09-27 18:48:08,945 - PIL.PngImagePlugin - DEBUG - STREAM b'IHDR' 16 13
# 2016-09-27 18:48:08,945 - PIL.PngImagePlugin - DEBUG - STREAM b'IDAT' 41 2880
# (224, 224, 3)

# %%
img[0][0]
# Out:
# '/JPEGImages/480p/bear/00004.jpg'
